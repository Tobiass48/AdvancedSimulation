# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import os

# %%
# Load Data
print("Working directory:", os.getcwd())

data_dir = "../data/raw/"
bridges_path = os.path.join(data_dir, "BMMS_overview.xlsx")
roads_path = os.path.join(data_dir, "_roads3.csv")
# Out:
# Working directory: C:\Users\audiv\PycharmProjects\AdvancedSimulation\EPA133a-G04-A3\data

# %%
# Read data
bridges = pd.read_excel(bridges_path)
roads = pd.read_csv(roads_path)
gdf = gpd.GeoDataFrame(roads, geometry=gpd.points_from_xy(roads.lon, roads.lat))

# %%
display(roads.head())
# Out:
#   road  chainage     lrp        lat        lon  gap       type  \
# 0   N1     0.000    LRPS  23.706028  90.443333  NaN     Others
# 1   N1     0.814   LRPSa  23.702917  90.450417  NaN    Culvert
# 2   N1     0.822   LRPSb  23.702778  90.450472  NaN  CrossRoad
# 3   N1     1.000  LRP001  23.702139  90.451972  NaN     KmPost
# 4   N1     2.000  LRP002  23.697889  90.460583  NaN     KmPost
#
#                                                 name
# 0  Start of Road  after Jatrabari Flyover infront...
# 1                                        Box Culvert
# 2                            Intersection with Z1101
# 3                                    Km post missing
# 4                                    Km post missing

# %%
# Plot function to plot the roads on a map
def plot_roads(gdf, label0, title, highlight=None, highlight_label=None, highlight2=None, highlight_label2=None):
    fig, ax = plt.subplots(figsize=(8,8))
    gdf.plot(ax=ax, color='blue', markersize=1, label=label0)

    if highlight is not None:
        highlight.plot(ax=ax, color='red', markersize=3, label=highlight_label)

    if highlight2 is not None:
        highlight2.plot(ax=ax, color='green', markersize=3, label=highlight_label2)

    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    ax.set_aspect('equal')
    fig.suptitle(title, fontsize=15)
    fig.tight_layout()
    plt.legend()
    plt.show()

# %%
plot_roads(gdf, 'All roads', 'Roads in the dataset', highlight=gdf[gdf['road'].str.contains('N')], highlight_label='N roads')

# %% [markdown]
# ### Identification of the N roads with intersections to the N1 and N2

# %%
n_roads = gdf[gdf['road'].str.contains('N')]
n1 = n_roads[n_roads['road'] == 'N1']
n2 = n_roads[n_roads['road'] == 'N2']

# %%
n_main = gpd.GeoDataFrame(pd.concat([n1, n2], ignore_index=True), crs=n1.crs)
n_main['buffer_geom'] = n_main.geometry.buffer(0.18)

# Combine all buffer geometries into a single geometry using unary_union
buffer_union = n_main['buffer_geom'].unary_union
roads_within = n_roads[n_roads.geometry.intersects(buffer_union)]

max_chainage = roads_within.groupby('road')['chainage'].max().reset_index()

# Filter: always include N1 and N2; for side roads, only include if max chainage > 25 km
valid_roads = max_chainage[
    (max_chainage['road'].isin(['N1', 'N2'])) |
    (max_chainage['chainage'] > 25)
]

# Filter the original roads based on the valid roads list
valid_roads = gdf[gdf['road'].isin(valid_roads['road'])]
print(f'Roads intersecting the N1 or N2 and longer than 25 km: {valid_roads.road.unique()}')

# Plot the final roads
plot_roads(
    gdf,
    label0='All roads',
    title='Roads in the Dataset',
    highlight=valid_roads,
    highlight_label='Valid Roads (N1, N2 or >25 km chainage)',
    highlight2=n_main,
    highlight_label2='N1 and N2'
)
# Out:
# C:\Users\audiv\AppData\Local\Temp\ipykernel_17448\1583411028.py:5: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   buffer_union = n_main['buffer_geom'].unary_union
# Roads intersecting the N1 or N2 and longer than 25 km: ['N1' 'N102' 'N104' 'N105' 'N2' 'N204' 'N207' 'N208']

# %% [markdown]
# ### Identify the intersection locations of the roads

# %%
# Loop through each road in valid roads, and display the crossroads
crossroads_list = []
for road in valid_roads['road'].unique():
    road_data = valid_roads[valid_roads['road'] == road]
    crossroads = road_data[road_data['type'].str.contains('CrossRoad')]

    # Add the beginning and end points of the road to the crossroads
    crossroads = pd.concat([crossroads, road_data.iloc[[0, -1]]])
    crossroads_list.append(crossroads)

possible_crossroads = pd.concat(crossroads_list, ignore_index=True)
display(possible_crossroads)

plot_roads(valid_roads, 'Valid Roads', 'Valid Roads with Possible Crossroads', highlight=possible_crossroads, highlight_label='Crossroads')
# Out:
#     road  chainage      lrp        lat        lon  gap                type  \
# 0     N1     0.822    LRPSb  23.702778  90.450472  NaN           CrossRoad
# 1     N1     7.181  LRP007a  23.697916  90.509278  NaN           CrossRoad
# 2     N1    85.897  LRP088a  23.459000  91.142333  NaN           CrossRoad
# 3     N1    87.366  LRP089c  23.446944  91.148139  NaN           CrossRoad
# 4     N1    91.583  LRP094a  23.419138  91.172194  NaN           CrossRoad
# 5     N1   140.251  LRP143a  23.047944  91.365139  NaN           CrossRoad
# 6     N1   145.409  LRP148a  23.009556  91.381360  NaN  CrossRoad / KmPost
# 7     N1   255.726  LRP259b  22.309694  91.915750  NaN           CrossRoad
# 8     N1   330.874  LRP335c  21.773722  92.084055  NaN           CrossRoad
# 9     N1     0.000     LRPS  23.706028  90.443333  NaN              Others
# 10    N1   462.254     LRPE  20.862917  92.298083  NaN              Others
# 11  N102    10.160  LRP010a  23.553111  91.063333  NaN           CrossRoad
# 12  N102    44.007  LRP043c  23.752556  91.094833  NaN           CrossRoad
# 13  N102     0.000     LRPS  23.478972  91.118194  NaN              Others
# 14  N102    82.682     LRPE  24.050611  91.114667  NaN              Others
# 15  N104     1.878  LRP001a  23.009528  91.381444  NaN           CrossRoad
# 16  N104     0.000     LRPS  23.009667  91.399416  NaN              Others
# 17  N104    49.630     LRPE  22.825749  91.101444  NaN              Others
# 18  N105     7.223  LRP007a  23.739666  90.586722  NaN           CrossRoad
# 19  N105    12.803  LRP012a  23.785194  90.568805  NaN           CrossRoad
# 20  N105    36.158  LRP036b  23.929833  90.453028  NaN           CrossRoad
# 21  N105    44.230  LRP044b  23.971416  90.396805  NaN           CrossRoad
# 22  N105    45.998  LRP046a  23.977499  90.380555  NaN           CrossRoad
# 23  N105     0.000     LRPS  23.690416  90.546611  NaN              Others
# 24  N105    48.870   LRP048  23.989527  90.358222  NaN     KmPost / Others
# 25    N2     6.076  LRP006a  23.746639  90.540277  NaN           CrossRoad
# 26    N2    11.464  LRP012a  23.785333  90.568555  NaN           CrossRoad
# 27    N2    43.747  LRP044b  23.982777  90.742444  NaN           CrossRoad
# 28    N2     0.000     LRPS  23.705917  90.521444  NaN              Others
# 29    N2   286.516     LRPE  25.157056  92.017638  NaN              Others
# 30  N204     0.000     LRPS  24.147916  91.346611  NaN              Others
# 31  N204    34.421     LRPE  24.267388  91.477138  NaN              Others
# 32  N207     0.000     LRPS  24.294861  91.510250  NaN              Others
# 33  N207    67.985     LRPE  24.626333  91.677527  NaN              Others
# 34  N208     0.000     LRPS  24.471360  91.765556  NaN              Others
# 35  N208    57.495     LRPE  24.877555  91.875360  NaN              Others
#
#                                                  name  \
# 0                             Intersection with Z1101
# 1            R110,Left to Demra, Right to Narayanganj
# 2                                    Cross road Z1029
# 3                               Cross Road with Z1052
# 4                   Left to Comilla Right to Noakhali
# 5                                               Z1031
# 6            Intersection with N104 / Km post missing
# 7                            Road to Kaliganj (Z1070)
# 8                             Intersection with Z1126
# 9   Start of Road  after Jatrabari Flyover infront...
# 10  End of Road at Shapla Chattar ,Teknaf Meet wit...
# 11              Z 1219 Left Nimsar Right    Burichang
# 12                                              Z1201
# 13                    Start of road from N1 Mainamati
# 14                            Meet with N 2 at Sanail
# 15                Right to Comilla Left to Chittagong
# 16                            Intersection with Z1031
# 17                 Meet with Z1441& Z1405 at Sonapur.
# 18                   Z1090, Majerchar -Kayetpara Road
# 19                      N2 Dhaka-Sylhet -Jaflong Road
# 20                        R301, Tongi- Panchhona road
# 21                                    Cros Road Z3008
# 22                          Dhaka -Mymensingh N3 Road
# 23  Starts of road from N1,Dhaka teknaf road at Ma...
# 24  B.Bridge 83 km,Tangail 60 km / End of Road  In...
# 25       Z1090 Left to Keyatpara,Right to Mahajanpur.
# 26                             Intersection with N105
# 27                                              Z2033
# 28                     Road Start from N1 at Katchpur
# 29                               Road End at Jaflong.
# 30               Road start from N2 at Jagannathganj.
# 31  Road End intersecting N2 at Shaistagonj Round ...
# 32                      Road start from N2 at Mirpur.
# 33  Road end with N2 at Mukti joddha Chattor Sherpur.
# 34                Road Start from N207 infront of RHD
# 35  Road end at Humayun Rashid Chattar, Intersecti...
#
#                      geometry
# 0   POINT (90.45047 23.70278)
# 1   POINT (90.50928 23.69792)
# 2     POINT (91.14233 23.459)
# 3   POINT (91.14814 23.44694)
# 4   POINT (91.17219 23.41914)
# 5   POINT (91.36514 23.04794)
# 6   POINT (91.38136 23.00956)
# 7   POINT (91.91575 22.30969)
# 8   POINT (92.08406 21.77372)
# 9   POINT (90.44333 23.70603)
# 10  POINT (92.29808 20.86292)
# 11  POINT (91.06333 23.55311)
# 12  POINT (91.09483 23.75256)
# 13  POINT (91.11819 23.47897)
# 14  POINT (91.11467 24.05061)
# 15  POINT (91.38144 23.00953)
# 16  POINT (91.39942 23.00967)
# 17  POINT (91.10144 22.82575)
# 18  POINT (90.58672 23.73967)
# 19   POINT (90.5688 23.78519)
# 20  POINT (90.45303 23.92983)
# 21  POINT (90.39681 23.97142)
# 22   POINT (90.38055 23.9775)
# 23  POINT (90.54661 23.69042)
# 24  POINT (90.35822 23.98953)
# 25  POINT (90.54028 23.74664)
# 26  POINT (90.56855 23.78533)
# 27  POINT (90.74244 23.98278)
# 28  POINT (90.52144 23.70592)
# 29  POINT (92.01764 25.15706)
# 30  POINT (91.34661 24.14792)
# 31  POINT (91.47714 24.26739)
# 32  POINT (91.51025 24.29486)
# 33  POINT (91.67753 24.62633)
# 34  POINT (91.76556 24.47136)
# 35  POINT (91.87536 24.87755)

# %%
# check if these possible crossroads intersect with at least 2 roads
crossroad_intersections = []

def check_crossroad_intersections(possible_crossroads, valid_roads):
    # Create a small buffer around each possible crossroad
    possible_crossroads['buffer_geom'] = possible_crossroads.geometry.buffer(0.005)

    for idx, crossroad in possible_crossroads.iterrows():
        # Check how many roads intersect with the buffer
        roads_intersecting = valid_roads[valid_roads.geometry.intersects(crossroad['buffer_geom'])]
        if roads_intersecting['road'].nunique() >= 2:
            crossroad_intersections.append(crossroad)

    return

check_crossroad_intersections(possible_crossroads, valid_roads)
crossroad_intersections = pd.DataFrame(crossroad_intersections).drop(columns='buffer_geom')
crossroad_intersections = gpd.GeoDataFrame(crossroad_intersections, geometry='geometry')
display(crossroad_intersections)

plot_roads(valid_roads, 'Valid Roads', 'Valid Roads with Crossroads', highlight=crossroad_intersections, highlight_label='Crossroads with at least 2 intersecting roads')
# Out:
#     road  chainage      lrp        lat        lon  gap                type  \
# 6     N1   145.409  LRP148a  23.009556  91.381360  NaN  CrossRoad / KmPost
# 13  N102     0.000     LRPS  23.478972  91.118194  NaN              Others
# 14  N102    82.682     LRPE  24.050611  91.114667  NaN              Others
# 15  N104     1.878  LRP001a  23.009528  91.381444  NaN           CrossRoad
# 19  N105    12.803  LRP012a  23.785194  90.568805  NaN           CrossRoad
# 23  N105     0.000     LRPS  23.690416  90.546611  NaN              Others
# 26    N2    11.464  LRP012a  23.785333  90.568555  NaN           CrossRoad
# 28    N2     0.000     LRPS  23.705917  90.521444  NaN              Others
# 30  N204     0.000     LRPS  24.147916  91.346611  NaN              Others
# 31  N204    34.421     LRPE  24.267388  91.477138  NaN              Others
# 32  N207     0.000     LRPS  24.294861  91.510250  NaN              Others
# 33  N207    67.985     LRPE  24.626333  91.677527  NaN              Others
# 34  N208     0.000     LRPS  24.471360  91.765556  NaN              Others
# 35  N208    57.495     LRPE  24.877555  91.875360  NaN              Others
#
#                                                  name  \
# 6            Intersection with N104 / Km post missing
# 13                    Start of road from N1 Mainamati
# 14                            Meet with N 2 at Sanail
# 15                Right to Comilla Left to Chittagong
# 19                      N2 Dhaka-Sylhet -Jaflong Road
# 23  Starts of road from N1,Dhaka teknaf road at Ma...
# 26                             Intersection with N105
# 28                     Road Start from N1 at Katchpur
# 30               Road start from N2 at Jagannathganj.
# 31  Road End intersecting N2 at Shaistagonj Round ...
# 32                      Road start from N2 at Mirpur.
# 33  Road end with N2 at Mukti joddha Chattor Sherpur.
# 34                Road Start from N207 infront of RHD
# 35  Road end at Humayun Rashid Chattar, Intersecti...
#
#                      geometry
# 6   POINT (91.38136 23.00956)
# 13  POINT (91.11819 23.47897)
# 14  POINT (91.11467 24.05061)
# 15  POINT (91.38144 23.00953)
# 19   POINT (90.5688 23.78519)
# 23  POINT (90.54661 23.69042)
# 26  POINT (90.56855 23.78533)
# 28  POINT (90.52144 23.70592)
# 30  POINT (91.34661 24.14792)
# 31  POINT (91.47714 24.26739)
# 32  POINT (91.51025 24.29486)
# 33  POINT (91.67753 24.62633)
# 34  POINT (91.76556 24.47136)
# 35  POINT (91.87536 24.87755)

# %% [markdown]
# These are the correct crossroads, however there are a few duplicate locations, with almost the same latitude and longitude. These duplicates will first be identified.

# %%
# Identify the (almost) duplicate locations

# Create a small buffer around each crossroad
crossroad_intersections['buffer_geom'] = crossroad_intersections.geometry.buffer(0.001)

# Check for intersections between the buffers
crossroad_duplicates = []
for idx, crossroad in crossroad_intersections.iterrows():
    intersections = crossroad_intersections[crossroad_intersections.geometry.intersects(crossroad['buffer_geom'])]
    if len(intersections) > 1:
        crossroad_duplicates.append(intersections.index)

display(crossroad_duplicates)
# Out:
# [Index([6, 15], dtype='int64'),
#  Index([6, 15], dtype='int64'),
#  Index([19, 26], dtype='int64'),
#  Index([19, 26], dtype='int64')]

# %% [markdown]
# So the duplicate crossroads are the one with index 6 & 15, and the one with index 19 & 26. In both cases we choose to keep the locations of the crossroad whcihc point originates from the N1 or N2 road data. The other ones are dropped in the code below.

# %%
# Remove the duplicates
try:
    crossroad_intersections = crossroad_intersections.drop(index=15)
    crossroad_intersections = crossroad_intersections.drop(index=19)
except KeyError:
    pass

# Remove the buffer geometry
try:
    crossroad_intersections = crossroad_intersections.drop(columns='buffer_geom')
except KeyError:
    pass

# display the final crossroads
display(crossroad_intersections)
# Out:
#     road  chainage      lrp        lat        lon  gap                type  \
# 6     N1   145.409  LRP148a  23.009556  91.381360  NaN  CrossRoad / KmPost
# 13  N102     0.000     LRPS  23.478972  91.118194  NaN              Others
# 14  N102    82.682     LRPE  24.050611  91.114667  NaN              Others
# 23  N105     0.000     LRPS  23.690416  90.546611  NaN              Others
# 26    N2    11.464  LRP012a  23.785333  90.568555  NaN           CrossRoad
# 28    N2     0.000     LRPS  23.705917  90.521444  NaN              Others
# 30  N204     0.000     LRPS  24.147916  91.346611  NaN              Others
# 31  N204    34.421     LRPE  24.267388  91.477138  NaN              Others
# 32  N207     0.000     LRPS  24.294861  91.510250  NaN              Others
# 33  N207    67.985     LRPE  24.626333  91.677527  NaN              Others
# 34  N208     0.000     LRPS  24.471360  91.765556  NaN              Others
# 35  N208    57.495     LRPE  24.877555  91.875360  NaN              Others
#
#                                                  name  \
# 6            Intersection with N104 / Km post missing
# 13                    Start of road from N1 Mainamati
# 14                            Meet with N 2 at Sanail
# 23  Starts of road from N1,Dhaka teknaf road at Ma...
# 26                             Intersection with N105
# 28                     Road Start from N1 at Katchpur
# 30               Road start from N2 at Jagannathganj.
# 31  Road End intersecting N2 at Shaistagonj Round ...
# 32                      Road start from N2 at Mirpur.
# 33  Road end with N2 at Mukti joddha Chattor Sherpur.
# 34                Road Start from N207 infront of RHD
# 35  Road end at Humayun Rashid Chattar, Intersecti...
#
#                      geometry
# 6   POINT (91.38136 23.00956)
# 13  POINT (91.11819 23.47897)
# 14  POINT (91.11467 24.05061)
# 23  POINT (90.54661 23.69042)
# 26  POINT (90.56855 23.78533)
# 28  POINT (90.52144 23.70592)
# 30  POINT (91.34661 24.14792)
# 31  POINT (91.47714 24.26739)
# 32  POINT (91.51025 24.29486)
# 33  POINT (91.67753 24.62633)
# 34  POINT (91.76556 24.47136)
# 35  POINT (91.87536 24.87755)

# %%
# Ensure valid_roads and crossroad_intersections are GeoDataFrames
if not isinstance(valid_roads, gpd.GeoDataFrame):
    valid_roads = gpd.GeoDataFrame(valid_roads, geometry='geometry')

if not isinstance(crossroad_intersections, gpd.GeoDataFrame):
    crossroad_intersections = gpd.GeoDataFrame(crossroad_intersections, geometry='geometry')

# %%
# Create a copy of valid_roads to avoid modifying a slice
valid_roads = valid_roads.copy()

# Check for intersections safely
valid_roads.loc[:, 'is_intersection'] = valid_roads.geometry.apply(
    lambda geom: crossroad_intersections.geometry.intersects(geom).any()
)

# %%
# Assign model_type based on intersection check
valid_roads.loc[:, 'model_type'] = valid_roads['is_intersection'].map({True: 'intersection', False: 'other'})

# %%
display(valid_roads)
# Out:
#       road  chainage      lrp        lat        lon  gap       type  \
# 0       N1     0.000     LRPS  23.706028  90.443333  NaN     Others
# 1       N1     0.814    LRPSa  23.702917  90.450417  NaN    Culvert
# 2       N1     0.822    LRPSb  23.702778  90.450472  NaN  CrossRoad
# 3       N1     1.000   LRP001  23.702139  90.451972  NaN     KmPost
# 4       N1     2.000   LRP002  23.697889  90.460583  NaN     KmPost
# ...    ...       ...      ...        ...        ...  ...        ...
# 3684  N208    54.585   LRP056  24.855778  91.888111  NaN     KmPost
# 3685  N208    55.510  LRP056a  24.861528  91.881860  NaN    Culvert
# 3686  N208    55.595   LRP057  24.861889  91.881027  NaN     KmPost
# 3687  N208    56.595   LRP058  24.869499  91.876027  NaN     KmPost
# 3688  N208    57.495     LRPE  24.877555  91.875360  NaN     Others
#
#                                                    name  \
# 0     Start of Road  after Jatrabari Flyover infront...
# 1                                           Box Culvert
# 2                               Intersection with Z1101
# 3                                       Km post missing
# 4                                       Km post missing
# ...                                                 ...
# 3684                                        Sylhet 7 km
# 3685                                        Box culvert
# 3686                                        Sylhet 6 km
# 3687                                        Sylhet 5 km
# 3688  Road end at Humayun Rashid Chattar, Intersecti...
#
#                        geometry  is_intersection    model_type
# 0     POINT (90.44333 23.70603)            False         other
# 1     POINT (90.45042 23.70292)            False         other
# 2     POINT (90.45047 23.70278)            False         other
# 3     POINT (90.45197 23.70214)            False         other
# 4     POINT (90.46058 23.69789)            False         other
# ...                         ...              ...           ...
# 3684  POINT (91.88811 24.85578)            False         other
# 3685  POINT (91.88186 24.86153)            False         other
# 3686  POINT (91.88103 24.86189)            False         other
# 3687   POINT (91.87603 24.8695)            False         other
# 3688  POINT (91.87536 24.87755)             True  intersection
#
# [3120 rows x 11 columns]

# %%
#filter bridges
bridges = bridges[bridges['road'].str.match(r'^(N1|N2)\d*$', na=False)]

# %%
# Rename columns to align with roads DataFrame (type -> model_type)
bridges = bridges.rename(columns={"type": "model_type"})
bridges = bridges.drop(columns=['length'])

# %%
# Add necessary default values for additional columns
bridges['length'] = bridges["chainage"].diff().abs().fillna(0)    # Default length for all bridges
bridges['model_type'] = "bridge"  # Standardize as "bridge"

# %%
# Remove unnecessary columns from bridges to match roads (if any)
if 'lrp' in bridges.columns:
    bridges_df = bridges.drop(columns=['lrp'])
if 'gap' in bridges.columns:
    bridges_df = bridges.drop(columns=['gap'])

# %%
# Keeping only the relevant and previously mentioned columns
bridges = bridges[['road','name','chainage','condition', 'model_type', 'length','lat','lon']]

# %%
bridges.head(20)
# Out:
#    road                         name  chainage condition model_type  length  \
# 0    N1                            .     1.800         A     bridge   0.000
# 1    N1                            .     4.925         A     bridge   3.125
# 2    N1            Kanch pur Bridge.     8.976         A     bridge   4.051
# 3    N1             NOYAPARA CULVERT    10.880         A     bridge   1.904
# 4    N1               ADUPUR CULVERT    10.897         A     bridge   0.017
# 5    N1  NAYABARI KASPUR BOX CULVERT    11.296         A     bridge   0.399
# 6    N1        KHAS PARA BOX CULVERT    12.239         A     bridge   0.943
# 7    N1        DAWAN BAG BOX CULVERT    12.253         A     bridge   0.014
# 8    N1          Madanpur Bridge.(L)    12.660         A     bridge   0.407
# 9    N1                MADAN PUR (R)    12.660         A     bridge   0.000
# 10   N1           MADANPUR BRIDGE(L)    12.660         A     bridge   0.000
# 11   N1           Madanpur Bridge(R)    12.688         A     bridge   0.028
# 12   N1          KAWTALA BOX CULVERT    13.574         A     bridge   0.886
# 13   N1         Darikandi Bridge (R)    17.222         A     bridge   3.648
# 14   N1         Darikandi Bridge (L)    17.222         A     bridge   0.000
# 15   N1           Sonakhal Bridge(L)    18.093         A     bridge   0.871
# 16   N1         KRIBORDI BOX CULVERT    19.760         A     bridge   1.667
# 17   N1          Marikhali Bridge(L)    21.184         A     bridge   1.424
# 18   N1          Marikhali Bridge(R)    21.184         A     bridge   0.000
# 19   N1             MARIKHALL BRIDGE    21.184         A     bridge   0.000
#
#           lat        lon
# 0   23.698739  90.458861
# 1   23.694664  90.487775
# 2   23.705060  90.523214
# 3   23.694391  90.537574
# 4   23.694302  90.537707
# 5   23.692360  90.540918
# 6   23.688412  90.548559
# 7   23.688320  90.548650
# 8   23.685583  90.551208
# 9   23.685583  90.551208
# 10  23.685583  90.551208
# 11  23.685362  90.551359
# 12  23.677803  90.555819
# 13  23.653972  90.577410
# 14  23.653972  90.577410
# 15  23.649754  90.584549
# 16  23.637954  90.593667
# 17  23.628467  90.602302
# 18  23.628467  90.602302
# 19  23.628467  90.602302

# %%
# Save the filtered roads and bridges for further processing
data_direct = "../data/"
valid_roads.to_csv(os.path.join(data_direct, "roads_filtered.csv"), index=False)
bridges.to_csv(os.path.join(data_direct, "bridges_filtered.csv"), index=False)

# %%
# Assuming you've already saved your filtered data:
roads = pd.read_csv("../data/old data/roads_filtered.csv")    # e.g. columns: [road, chainage, lat, lon, type, name, is_intersection, ...]
bridges = pd.read_csv("../data/old data/bridges_filtered.csv") # e.g. columns: [road, km (chainage), lat, lon, type, name, condition, length, ...]

# %%
# 2.1 Rename chainage column if needed
# roads may already have a 'chainage' column, so no change is required.
# If your chainage column is named differently (e.g. "km"), rename it:
# roads.rename(columns={'km': 'chainage'}, inplace=True)

# 2.2 Create a new DataFrame with the columns you need
roads_df = pd.DataFrame()
roads_df['road'] = roads['road']
roads_df['chainage'] = roads['chainage']
roads_df['lat'] = roads['lat']
roads_df['lon'] = roads['lon']
roads_df['name'] = roads['name']

# We'll set 'condition' to NaN for roads (since it usually applies to bridges)
roads_df['condition'] = np.nan

# We'll leave 'length' at 0 or NaN for now—unless you have a specific way
# to calculate length for road segments:
roads_df['length'] = 0

# 2.3 Determine model_type for roads
#    - If is_intersection == True, then 'intersection'
#    - Otherwise, default to 'link'
roads_df['model_type'] = np.where(
    roads['is_intersection'] == True,
    'intersection',
    'link'
)

# %%
bridges_df = pd.DataFrame()
bridges_df['road'] = bridges['road']

# If your bridges have a column called 'km' for chainage, rename it:
# bridges.rename(columns={'km': 'chainage'}, inplace=True)
bridges_df['chainage'] = bridges['chainage']  # or 'chainage' if already named that

bridges_df['lat'] = bridges['lat']
bridges_df['lon'] = bridges['lon']
bridges_df['name'] = bridges['name']
bridges_df['condition'] = bridges['condition']
bridges_df['length'] = bridges['length']  # from the bridges data
bridges_df['model_type'] = 'bridge'

# %%
df_combined = pd.concat([roads_df, bridges_df], ignore_index=True)

# %%
def label_sourcesink(group):
    min_chain = group['chainage'].min()
    max_chain = group['chainage'].max()

    # Mark rows that match min or max chainage and are not labeled as 'intersection'
    mask_min = (group['chainage'] == min_chain) & (group['model_type'] != 'intersection')
    mask_max = (group['chainage'] == max_chain) & (group['model_type'] != 'intersection')

    group.loc[mask_min, 'model_type'] = 'sourcesink'
    group.loc[mask_max, 'model_type'] = 'sourcesink'

    return group

df_combined = df_combined.groupby('road', group_keys=False).apply(label_sourcesink)
display(df_combined[df_combined['model_type'] == 'intersection'])
# Out:
#       road  chainage        lat        lon  \
# 335     N1   145.409  23.009556  91.381360
# 1339  N102     0.000  23.478972  91.118194
# 1557  N102    82.682  24.050611  91.114667
# 1681  N105     0.000  23.690416  90.546611
# 1798    N2     0.000  23.705917  90.521444
# 1816    N2    11.464  23.785333  90.568555
# 2684  N204     0.000  24.147916  91.346611
# 2776  N204    34.421  24.267388  91.477138
# 2777  N207     0.000  24.294861  91.510250
# 2942  N207    67.985  24.626333  91.677527
# 2943  N208     0.000  24.471360  91.765556
# 3119  N208    57.495  24.877555  91.875360
#
#                                                    name condition  length  \
# 335            Intersection with N104 / Km post missing       NaN     0.0
# 1339                    Start of road from N1 Mainamati       NaN     0.0
# 1557                            Meet with N 2 at Sanail       NaN     0.0
# 1681  Starts of road from N1,Dhaka teknaf road at Ma...       NaN     0.0
# 1798                     Road Start from N1 at Katchpur       NaN     0.0
# 1816                             Intersection with N105       NaN     0.0
# 2684               Road start from N2 at Jagannathganj.       NaN     0.0
# 2776  Road End intersecting N2 at Shaistagonj Round ...       NaN     0.0
# 2777                      Road start from N2 at Mirpur.       NaN     0.0
# 2942  Road end with N2 at Mukti joddha Chattor Sherpur.       NaN     0.0
# 2943                Road Start from N207 infront of RHD       NaN     0.0
# 3119  Road end at Humayun Rashid Chattar, Intersecti...       NaN     0.0
#
#         model_type
# 335   intersection
# 1339  intersection
# 1557  intersection
# 1681  intersection
# 1798  intersection
# 1816  intersection
# 2684  intersection
# 2776  intersection
# 2777  intersection
# 2942  intersection
# 2943  intersection
# 3119  intersection

# %%
#df_combined = df_combined.sort_values(by=['road', 'chainage']).reset_index(drop=True)

df_combined = df_combined.sort_values(by=['chainage']).reset_index(drop=True)

# %%
start_id = 1000000
df_combined['id'] = range(start_id, start_id + len(df_combined))

# %%
df_combined.columns
# Out:
# Index(['road', 'chainage', 'lat', 'lon', 'name', 'condition', 'length',
#        'model_type', 'id'],
#       dtype='object')

# %%
# Step 1: Separate intersection rows
intersection_rows = df_combined[df_combined["model_type"] == "intersection"]

# Step 2: Process non-intersection rows
non_intersection_rows = df_combined[df_combined["model_type"] != "intersection"]

# Mark bridges with "(L)" in the name
non_intersection_rows["has_L"] = non_intersection_rows["name"].str.contains(r"\(L\)", case=False, na=False)

# Sort non-intersection rows so that bridges with "(L)" come first
non_intersection_rows = non_intersection_rows.sort_values(
    by=["chainage", "has_L"], ascending=[True, False]
)

# Drop duplicates in non-intersection rows
non_intersection_rows = non_intersection_rows.drop_duplicates(subset="chainage", keep="first")

# Clean up helper columns
non_intersection_rows = non_intersection_rows.drop(columns=["has_L"])

# Step 3: Combine back intersection rows with the deduplicated non-intersection rows
df_combined = pd.concat([intersection_rows, non_intersection_rows]).sort_values(by="chainage")

# Step 4: Recalculate the length based on chainage
df_combined['length'] = df_combined["chainage"].diff().abs().fillna(0)

# Make sure the length is numeric
df_combined["length"] = pd.to_numeric(df_combined["length"], errors="coerce")
# Out:
# C:\Users\audiv\AppData\Local\Temp\ipykernel_17448\626621763.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_intersection_rows["has_L"] = non_intersection_rows["name"].str.contains(r"\(L\)", case=False, na=False)

# %%
display(df_combined[df_combined['model_type'] == 'intersection'])
# Out:
#       road  chainage        lat        lon  \
# 1     N102     0.000  23.478972  91.118194
# 2     N105     0.000  23.690416  90.546611
# 3       N2     0.000  23.705917  90.521444
# 4     N204     0.000  24.147916  91.346611
# 5     N207     0.000  24.294861  91.510250
# 6     N208     0.000  24.471360  91.765556
# 365     N2    11.464  23.785333  90.568555
# 1258  N204    34.421  24.267388  91.477138
# 1872  N208    57.495  24.877555  91.875360
# 2028  N207    67.985  24.626333  91.677527
# 2184  N102    82.682  24.050611  91.114667
# 2722    N1   145.409  23.009556  91.381360
#
#                                                    name condition  length  \
# 1                       Start of road from N1 Mainamati       NaN   0.000
# 2     Starts of road from N1,Dhaka teknaf road at Ma...       NaN   0.000
# 3                        Road Start from N1 at Katchpur       NaN   0.000
# 4                  Road start from N2 at Jagannathganj.       NaN   0.000
# 5                         Road start from N2 at Mirpur.       NaN   0.000
# 6                   Road Start from N207 infront of RHD       NaN   0.000
# 365                              Intersection with N105       NaN   0.042
# 1258  Road End intersecting N2 at Shaistagonj Round ...       NaN   0.006
# 1872  Road end at Humayun Rashid Chattar, Intersecti...       NaN   0.169
# 2028  Road end with N2 at Mukti joddha Chattor Sherpur.       NaN   0.115
# 2184                            Meet with N 2 at Sanail       NaN   0.245
# 2722           Intersection with N104 / Km post missing       NaN   0.087
#
#         model_type       id
# 1     intersection  1000001
# 2     intersection  1000002
# 3     intersection  1000003
# 4     intersection  1000004
# 5     intersection  1000005
# 6     intersection  1000006
# 365   intersection  1000365
# 1258  intersection  1001258
# 1872  intersection  1001872
# 2028  intersection  1002028
# 2184  intersection  1002184
# 2722  intersection  1002722

# %%
# 2. For each road, shift the chainage and compute the difference
#df_combined['prev_chainage'] = df_combined.groupby('road')['chainage'].shift(1)

# 3. Calculate segment length as chainage - prev_chainage
#df_combined['length'] = df_combined['chainage'] - df_combined['prev_chainage']

# 4. For the first row of each road (where prev_chainage is NaN), fill with 0
#df_combined['length'] = df_combined['length'].fillna(0)

# 5. Drop the helper column if you like
#df_combined.drop(columns=['prev_chainage'], inplace=True)

# Now df_combined['length'] contains the segment length in the same unit as chainage.

# %%
df_combined = df_combined[[
    'road',
    'id',
    'model_type',
    'condition',
    'name',
    'lat',
    'lon',
    'length'
]]

# %%
display(df_combined.head(40))
df_combined.to_csv("../data/final_n1_n2.csv", index=False)
# Out:
#     road       id    model_type condition  \
# 1   N102  1000001  intersection       NaN
# 2   N105  1000002  intersection       NaN
# 3     N2  1000003  intersection       NaN
# 4   N204  1000004  intersection       NaN
# 5   N207  1000005  intersection       NaN
# 6   N208  1000006  intersection       NaN
# 0     N1  1000000    sourcesink       NaN
# 8   N205  1000008    sourcesink         A
# 9   N105  1000009        bridge         C
# 10  N107  1000010    sourcesink         A
# 11  N209  1000011    sourcesink         A
# 12    N2  1000012          link       NaN
# 13  N207  1000013          link       NaN
# 14  N102  1000014          link       NaN
# 15  N104  1000015        bridge         A
# 16  N110  1000016    sourcesink         A
# 17  N107  1000017        bridge         B
# 19  N104  1000019        bridge         B
# 20  N104  1000020          link       NaN
# 21  N207  1000021          link       NaN
# 22  N207  1000022        bridge         B
# 24  N106  1000024    sourcesink         C
# 25  N207  1000025          link       NaN
# 26  N206  1000026    sourcesink         A
# 27  N204  1000027          link       NaN
# 28  N204  1000028        bridge         C
# 29  N204  1000029          link       NaN
# 30  N106  1000030        bridge         A
# 31  N208  1000031        bridge         A
# 32  N204  1000032        bridge         A
# 35    N1  1000035          link       NaN
# 36  N106  1000036        bridge         C
# 37    N1  1000037          link       NaN
# 38  N110  1000038        bridge         A
# 39  N204  1000039          link       NaN
# 40  N108  1000040    sourcesink         A
# 42  N208  1000042        bridge         A
# 43  N206  1000043    sourcesink         B
# 44  N110  1000044        bridge         A
# 45  N102  1000045        bridge         A
#
#                                                  name        lat        lon  \
# 1                     Start of road from N1 Mainamati  23.478972  91.118194
# 2   Starts of road from N1,Dhaka teknaf road at Ma...  23.690416  90.546611
# 3                      Road Start from N1 at Katchpur  23.705917  90.521444
# 4                Road start from N2 at Jagannathganj.  24.147916  91.346611
# 5                       Road start from N2 at Mirpur.  24.294861  91.510250
# 6                 Road Start from N207 infront of RHD  24.471360  91.765556
# 0   Start of Road  after Jatrabari Flyover infront...  23.706028  90.443333
# 8                                 CHONDRI BOX CULVERT  24.867910  91.857191
# 9                                            MODONPUR  23.690608  90.546717
# 10                                   KALURGHAT BRIDGE  22.394042  91.892057
# 11                                  MENIKHOLA CULVERT  24.878769  91.875310
# 12                                      Sylhet 230 km  23.706889  90.520472
# 13                                       Pipe culvert  24.296416  91.512083
# 14                                        Box Culvert  23.481583  91.116777
# 15                              Shasaugtachha culvert  23.009362  91.396149
# 16                                       zilinza kali  21.424832  92.020022
# 17                                 Kalurghat Bridge-2  22.391645  91.893384
# 19                           S.S.SK ROAD SLAB CULVERT  23.009302  91.395512
# 20                                        Box culvert  23.009278  91.395250
# 21                                       Bridge Start  24.297583  91.513528
# 22                                      Mirpur Bridge  24.297565  91.513652
# 24                             TANARI BOTTOLA CULVERT  22.397475  91.820037
# 25                                         Bridge end  24.297555  91.513722
# 26                                          NOYAR PUL  24.889323  91.868695
# 27                                        Box culvert  24.148361  91.351389
# 28                               JOGIDISH PUR TEMORIA  24.148351  91.351389
# 29                                     Hobiganj 31 km  24.147555  91.351361
# 30                             TANARI BOTTOLA CULVERT  22.399000  91.819813
# 31                                RATAULI BOX CULVERT  24.474195  91.770250
# 32                               Telaria Chara Bridge  24.146027  91.351306
# 35                                        Box Culvert  23.702917  90.450417
# 36                                 TANARI BOX CULVERT  22.400440  91.819371
# 37                            Intersection with Z1101  23.702778  90.450472
# 38                                       JANAGONA B0X  21.424616  92.015734
# 39                                         Bridge end  24.145722  91.351306
# 40                     SOUTH KAOCHIA RCC GIDER BRIDGE  22.103743  92.082378
# 42                              NAYANAGAR BOX CULVERT  24.475316  91.772106
# 43                                          NAYAR PUL  24.891431  91.871006
# 44                                          DANARGONA  21.424587  92.014666
# 45                               PORISPUR BOX CULVERT  23.486582  91.113418
#
#     length
# 1    0.000
# 2    0.000
# 3    0.000
# 4    0.000
# 5    0.000
# 6    0.000
# 0    0.000
# 8    0.022
# 9    0.002
# 10   0.028
# 11   0.104
# 12   0.010
# 13   0.060
# 14   0.103
# 15   0.020
# 16   0.022
# 17   0.011
# 19   0.035
# 20   0.028
# 21   0.012
# 22   0.014
# 24   0.006
# 25   0.002
# 26   0.054
# 27   0.012
# 28   0.001
# 29   0.084
# 30   0.012
# 31   0.008
# 32   0.156
# 35   0.008
# 36   0.004
# 37   0.004
# 38   0.002
# 39   0.024
# 40   0.034
# 42   0.025
# 43   0.021
# 44   0.006
# 45   0.050

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_combined = pd.read_csv("../data/old data/final_n1_n2.csv")

colors = {
    'bridge': 'yellow',
    'link': 'blue',
    'sourcesink': 'black',
    'intersection': 'red'
}

markers = {
    'bridge': 'x',
    'link': 'o',
    'sourcesink': 's',
    'intersection': '*'
}

marker_sizes = {
    'bridge': 60,
    'link': 10,
    'sourcesink': 20,
    'intersection': 40
}

plt.figure(figsize=(10, 8))

for model_type, color in colors.items():
    subset = df_combined[df_combined['model_type'] == model_type]
    plt.scatter(subset['lon'], subset['lat'], c=color, label=model_type, s=marker_sizes[model_type],
                marker=markers[model_type])

for road in df_combined['road'].unique():
    first_point = df_combined[df_combined['road'] == road].iloc[0]
    plt.text(first_point['lon'], first_point['lat'], road, fontsize=9, ha='right')

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Road Network Plot (N1 & N2 Only)')
plt.legend()
plt.show()
